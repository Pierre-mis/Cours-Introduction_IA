# %% [markdown]
# # TP 1 : IA & Santé - Diagnostic Cancer (Classification) 🩺
# (SUJET GUIDÉ)
#
# **Objectif :** Prédire 'Bénin' ou 'Malin' et comprendre les métriques critiques en santé (Rappel, ROC).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

np.random.seed(42)

# %% [markdown]
# ## 1. Chargement et Exploration

# %%
data = load_breast_cancer(as_frame=True)
df = data.frame
X = data.data
y = data.target
print("Classes :", data.target_names) # 0 = Malignant, 1 = Benign
df.head()

# %% [markdown]
# ### 1.1 Analyse Exploratoire

# %% [markdown]
# Vérifions le type des données et s'il manque des valeurs.

# %%
# TODO: Affichez les infos du DataFrame (df.info())
# TODO: Affichez les statistiques descriptives (df.describe())
# TODO: Vérifiez s'il y a des valeurs manquantes (isnull().sum())

# %% [markdown]
# ### Visualisation des Données

# %% [markdown]
# #### A. Équilibre des classes

# %%
# 1. Affichez la distribution des classes avec sns.countplot
# TODO: Utilisez sns.countplot pour visualiser la variable 'target'

# %% [markdown]
# #### B. Corrélations

# %%
# 2. Affichez la matrice de corrélation (sns.heatmap) sur une sélection de colonnes
# TODO: Sélectionnez quelques colonnes pertinentes (ex: radius, texture) et affichez la heatmap

# %% [markdown]
# #### C. Comparaison (Boxplots)

# %%
# 3. Utilisez sns.boxplot pour comparer 'mean radius' selon la 'target'
# TODO: Créez un boxplot pour voir l'impact du rayon sur le diagnostic

# %% [markdown]
# ## 2. Modélisation (KNN vs RF)

# %%
# 1. Divisez les données en Train/Test (80% train, 20% test)
# X_train, X_test, y_train, y_test = train_test_split(..., test_size=0.2, random_state=42)

# 2. Particulièrement pour le KNN, il est crucial de mettre à l'échelle les données
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(...)
# X_test_scaled = scaler.transform(...) # Attention: transform uniquement sur le test !

# %%
# 3. Entraînez un KNN (n_neighbors=5)
# knn = ...
# knn.fit(...)

# 4. Entraînez un Random Forest (n_estimators=100)
# rf = ...
# rf.fit(...)

# 5. Affichez les scores (accuracy)
# print(f"KNN Accuracy: {knn.score(...)}")
# print(f"RF Accuracy: {rf.score(...)}")

# %% [markdown]
# ## 3. Analyse Avancée : Courbe ROC

# %%
# Pour tracer la courbe ROC, il nous faut les probabilités et pas juste les classes.
# y_probs = rf.predict_proba(X_test_scaled)[:, 0] # On prend la probabilité d'être classe 0 (Malignant)

# Calculez les métriques avec roc_curve
# fpr, tpr, _ = roc_curve(..., y_probs)
# roc_auc = auc(fpr, tpr)

# Tracez la courbe avec plt.plot(fpr, tpr)

# %% [markdown]
# ## 4. Explicabilité : Pourquoi ce diagnostic ?

# %% [markdown]
# ### A. Feature Importance
# Le modèle Random Forest peut nous dire quelles colonnes ont le plus pesé dans sa décision.
# Utilisez `rf.feature_importances_` pour récupérer les scores et affichez-les avec un graphique à barres.

# %%
# TODO: Récupérez rf.feature_importances_
# TODO: Triez les valeurs et affichez un barplot (plt.bar) des 10 variables les plus importantes

# %% [markdown]
# ### B. Analyse des Erreurs
# Essayez de trouver un cas où le modèle s'est trompé (Faux Négatif ou Faux Positif).

# %%
# TODO: Faites les prédictions sur le test set
# TODO: Cherchez un index où y_test != y_pred (ex: un malade prédit sain)
# TODO: Affichez les caractéristiques de ce patient (X_test) pour comprendre l'erreur
