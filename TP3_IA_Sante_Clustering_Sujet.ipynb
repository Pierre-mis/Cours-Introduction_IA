# %% [markdown]
# # TP 3 : IA & Santé - Profilage (Clustering) 🧬
# (SUJET - NIVEAU INTERMÉDIAIRE)
#
# **Objectif :** Sans utiliser le diagnostic connu, retrouver des groupes de patients.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
data = load_breast_cancer(as_frame=True); X = data.data; df = data.frame; X_scaled = StandardScaler().fit_transform(X)

# %% [markdown]
# ## 1. Méthode du Coude (Elbow Method)

# %%
# TODO: Implémentez la "Méthode du Coude"
# 1. Faites une boucle variant k de 1 à 10.
# 2. Pour chaque k, entraînez un KMeans.
# 3. Stockez la valeur de 'inertia_' dans une liste.
# 4. Tracez la courbe (k vs inertie).

# %% [markdown]
# ## 2. Dendrogramme (Clustering Hiérarchique)

# %%
# TODO: Utilisez 'linkage' (scipy) sur un sous-échantillon (ex: X_scaled[:50])
# TODO: Affichez le dendrogram

# %% [markdown]
# ## 3. Interprétation : Qui sont ces profils ?

# %% [markdown]
# ### A. Profilage
# Calculez la moyenne des variables (`mean radius`, `mean texture`) pour chaque Cluster.
# Qui est le groupe "Malade" ? Qui est le groupe "Sain" ?

# %%
# df['Cluster'] = km.labels_
# print(df.groupby('Cluster').mean())

# %% [markdown]
# ### B. Comparaison avec la réalité
# Comparez vos clusters avec `data.target` (les vrais diagnostics).
# Le clustering a-t-il réussi à séparer les malades des sains ?

# %%
# confusion_matrix(data.target, km.labels_)
