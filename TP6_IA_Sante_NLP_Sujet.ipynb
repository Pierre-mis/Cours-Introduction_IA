# %% [markdown]
# # TP 6 : IA & Santé - NLP 📑
# (SUJET - NIVEAU AVANCÉ)
#
# **Objectif :** Classifer des rapports médicaux avec TF-IDF.

# %%
# À VOUS DE JOUER
# 1. Chargez le dataset (fetch_20newsgroups, cat='sci.med').
# 2. Vectorisez le texte avec TfidfVectorizer.
# 3. Visualisez les mots importants (WordCloud).
# 4. Entraînez un classifieur (Naive Bayes ou SVM).
# 5. Testez sur une phrase inventée.
